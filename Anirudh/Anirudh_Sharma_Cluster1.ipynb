# %%
import pandas as pd
import numpy as np
import joblib

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the data

# %%
RNDM_SEED = 12
df = pd.read_csv('cluster_1_train_data.csv')
df.head()
# Out:
#    Index  Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0      2          0                                           0.571150
# 1      9          0                                           0.522742
# 2     13          0                                           0.590114
# 3     14          0                                           0.501877
# 4     16          0                                           0.480866
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.620148
# 1                                 0.579536
# 2                                 0.611753
# 3                                 0.547700
# 4                                 0.546991
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.624177
# 1                                           0.575566
# 2                                           0.634991
# 3                                           0.562557
# 4                                           0.529953
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.612275                      0.612282
# 1                 0.619114                      0.619114
# 2                 0.611403                      0.611403
# 3                 0.647782                      0.647782
# 4                 0.595994                      0.594863
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.999163                    0.797654
# 1                0.999075                    0.797525
# 2                0.999206                    0.797672
# 3                0.999076                    0.797459
# 4                0.998926                    0.797466
#
#     After-tax net Interest Rate  ...   Total assets to GNP price  \
# 0                      0.809533  ...                    0.006022
# 1                      0.809443  ...                    0.002259
# 2                      0.809558  ...                    0.009663
# 3                      0.809416  ...                    0.000787
# 4                      0.809373  ...                    0.007207
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.625306                0.612271
# 1             0.624266                0.619116
# 2             0.622830                0.611404
# 3             0.624350                0.647779
# 4             0.624691                0.595993
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.843294              0.278927
# 1                             0.841468              0.275937
# 2                             0.842483              0.275332
# 3                             0.840367              0.276460
# 4                             0.840578              0.276414
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026816
# 1                             0.026791
# 2                             0.026791
# 3                             0.027138
# 4                             0.026797
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.565276                   1
# 1                                           0.565158                   1
# 2                                           0.565158                   1
# 3                                           0.566402                   1
# 4                                           0.565186                   1
#
#     Equity to Liability  Cluster_ID
# 0              0.033034           1
# 1              0.087300           1
# 2              0.159042           1
# 3              0.064648           1
# 4              0.066087           1
#
# [5 rows x 98 columns]

# %%
y = df['Bankrupt?']
X = df.drop(columns = ['Index', 'Bankrupt?', 'Cluster_ID'])

print(f'shape of y: {y.shape}')
print(f'shape of X: {X.shape}')
# Out:
# shape of y: (1693,)
# shape of X: (1693, 95)

# %% [markdown]
# ### Preprocessing

# %%
rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced')
rf.fit(X, y)

imp = rf.feature_importances_ 
feature_scores = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf.feature_importances_
}).sort_values(by='Importance', ascending=False)


top_features = feature_scores['Feature'].tolist()
print(top_features)
# Out:
# [' Net Value Per Share (A)', ' Average Collection Days', ' Net Income to Total Assets', ' Net profit before tax/Paid-in capital', ' Total debt/Total net worth', ' Total income/Total expense', ' Inventory/Current Liability', ' Accounts Receivable Turnover', ' Net Value Per Share (C)', ' Inventory/Working Capital', ' Net Value Per Share (B)', ' Inventory and accounts receivable/Net value', ' Research and development expense rate', ' Cash/Total Assets', ' Current Liability to Equity', ' Cash/Current Liability', ' Retained Earnings to Total Assets', ' Per Share Net profit before tax (Yuan ¥)', ' Operating profit per person', ' Current Liabilities/Equity', ' Operating profit/Paid-in capital', ' Net Worth Turnover Rate (times)', ' Net worth/Assets', ' CFO to Assets', ' Persistent EPS in the Last Four Seasons', ' Total Asset Turnover', ' Revenue per person', ' After-tax net Interest Rate', " Net Income to Stockholder's Equity", ' Cash Turnover Rate', ' ROA(A) before interest and % after tax', ' Current Liability to Assets', ' Realized Sales Gross Margin', ' Borrowing dependency', ' Tax rate (A)', ' Equity to Liability', ' Realized Sales Gross Profit Growth Rate', ' Gross Profit to Sales', ' Cash flow rate', ' Net Value Growth Rate', ' No-credit Interval', ' Revenue Per Share (Yuan ¥)', ' Interest Expense Ratio', ' ROA(C) before interest and depreciation before interest', ' Operating Profit Per Share (Yuan ¥)', ' ROA(B) before interest and depreciation after tax', ' Liability to Equity', ' Cash Flow Per Share', ' Operating Funds to Liability', ' Cash Flow to Sales', ' Regular Net Profit Growth Rate', ' Inventory Turnover Rate (times)', ' Continuous Net Profit Growth Rate', ' Current Asset Turnover Rate', ' Cash Flow to Liability', ' Total expense/Assets', ' Pre-tax net Interest Rate', ' Current Liability to Liability', ' Current Liabilities/Liability', ' Interest Coverage Ratio (Interest expense to EBIT)', ' Operating Profit Growth Rate', ' Operating Expense Rate', ' After-tax Net Profit Growth Rate', ' Long-term fund suitability ratio (A)', ' Quick Assets/Total Assets', ' Total assets to GNP price', ' Degree of Financial Leverage (DFL)', ' Quick Assets/Current Liability', ' Allocation rate per person', ' Cash Flow to Total Assets', ' Working Capital/Equity', ' Fixed Assets to Assets', ' Contingent liabilities/Net worth', ' Cash Reinvestment %', ' Working capitcal Turnover Rate', ' Current Liability to Current Assets', ' Working Capital to Total Assets', ' Total Asset Return Growth Rate Ratio', ' Total Asset Growth Rate', ' Operating Profit Rate', ' Quick Asset Turnover Rate', ' Current Ratio', ' Non-industry income and expenditure/revenue', ' Debt ratio %', ' Long-term Liability to Current Assets', ' Cash Flow to Equity', ' Equity to Long-term Liability', ' Quick Ratio', ' Operating Gross Margin', ' Interest-bearing debt interest rate', ' Continuous interest rate (after tax)', ' Fixed Assets Turnover Frequency', ' Current Assets/Total Assets', ' Liability-Assets Flag', ' Net Income Flag']

# %%
feature_scores.sort_values(by = 'Importance').plot(
    kind='barh', 
    color='teal', 
    figsize=(20, 20)
)

plt.title('Top Features by Importance (Random Forest)')
plt.xlabel('Importance Score')
plt.show()

# %% [markdown]
# Based on this plot, I think it only makes sense to keep features with importance scores more than 0.01

# %%
feature_scores.head()
# Out:
#                                    Feature  Importance
# 16                 Net Value Per Share (A)    0.056996
# 46                 Average Collection Days    0.048219
# 85              Net Income to Total Assets    0.047234
# 42   Net profit before tax/Paid-in capital    0.041923
# 35              Total debt/Total net worth    0.039119

# %%
significant_features = feature_scores[feature_scores['Importance'] > 0.01]

# %%
significant_features.shape
# Out:
# (38, 2)

# %%
selected_cols = significant_features['Feature'].tolist()
top_X = X[selected_cols]

# %%
top_X.shape
# Out:
# (1693, 38)

# %%
# Lets check how many values actually are 1
ones = y.value_counts()
ones
# Out:
# Bankrupt?
# 0    1690
# 1       3
# Name: count, dtype: int64

# %%
# Lets scale the data  
median_imputer = SimpleImputer(strategy='median')
X_no_missing = median_imputer.fit_transform(top_X)

std_scaler = StandardScaler()
X_final = std_scaler.fit_transform(X_no_missing)

n_features = X.shape[1]

X_train, X_val, y_train, y_val = train_test_split(top_X, y, test_size = 0.2, random_state = RNDM_SEED)

# %%
print(f'Shape of X_train is: {X_train.shape}')
print(f'Shape of X_val is: {X_val.shape}')
print(f'Shape of y_train is: {y_train.shape}')
print(f'Shape of y_val is: {y_val.shape}')
# Out:
# Shape of X_train is: (1354, 38)
# Shape of X_val is: (339, 38)
# Shape of y_train is: (1354,)
# Shape of y_val is: (339,)

# %% [markdown]
# ### Building model

# %%
# Let's use random forest and logistic regression since they are robust to imbalance data
estimators = [
    ('rf', RandomForestClassifier(
        n_estimators=50, 
        random_state=42, 
        class_weight='balanced'
    )),
    ('lr', LogisticRegression(
        random_state=42, 
        class_weight='balanced', 
        max_iter=1000
    ))
]

clf = VotingClassifier(estimators=estimators, voting='soft')

clf.fit(X_train, y_train)
y_proba = clf.predict_proba(X_val)[:, 1]

# %%
def get_constrained_threshold(y_true, y_proba, constraint=0.20):
    """
    This function basically finds threshold while making sure
    that Recall is maximised and Positive Prediction Rate is low.
    """
    best_thresh = 0.5
    best_recall = -1
    
    # Iteratinf from high to low
    thresholds = np.arange(0.1, 0.99, 0.05)
    
    print(f"\n--- Tuning Threshold (Max Positive Rate: {constraint:.0%}) ---")

    for thresh in thresholds:
        y_pred = (y_proba >= thresh).astype(int)
        
        #Calculating positive rate
        pos_rate = np.mean(y_pred)
        
        if pos_rate >= constraint:
            continue 
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0,1]).ravel()
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        
        if recall > best_recall:
            best_recall = recall
            best_thresh = thresh

    print(f"  > Best Threshold: {best_thresh:.2f} (Recall: {best_recall:.3f})")
    return best_thresh

best_threshold = get_constrained_threshold(y_val, y_proba)
# Out:
# --- Tuning Threshold (Max Positive Rate: 20%) ---
#   > Best Threshold: 0.30 (Recall: 0.000)

# %% [markdown]
# ### Making predictions

# %%
y_final_pred = (y_proba >= best_threshold).astype(int)
tn, fp, fn, tp = confusion_matrix(y_val, y_final_pred, labels=[0,1]).ravel()

results_data = {
    "Subgroup_ID": 1,
    "Num_Companies": len(y),
    "Num_Bankrupt": y.sum(),
    "Stacking_TT_Correct": tp,
    "Stacking_TF_Missed": fn,
    "N_Features": n_features
}

results_df = pd.DataFrame([results_data])

print("\n=== TABLE 3 DATA ===")
print(results_df.T)
# Out:
# === TABLE 3 DATA ===
#                         0
# Subgroup_ID             1
# Num_Companies        1693
# Num_Bankrupt            3
# Stacking_TT_Correct     0
# Stacking_TF_Missed      0
# N_Features             95

# %% [markdown]
# ### Saving the model

# %%
artifact = {
    'model': clf,
    'preprocessing': {
        'scaler': std_scaler,
        'imputer': median_imputer
    },
    'params': {
        'threshold': best_threshold,
        'columns': X.columns.tolist()
    }
}

# Saving
fname = f"member_model_cluster_1.joblib"
joblib.dump(artifact, fname)
print(f"Saved: {fname}")
# Out:
# Saved: member_model_cluster_1.joblib
